# %%
import pandas as pd

data= pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vR1OYsz7cNFWMK9ZXe_6JgTu3kz1ywcVwajRlnKxKyNxot71TfC728ylqnsNuv7dA/pub?gid=641624856&single=true&output=csv',header=[0,1,2])
data
# Out:
#     Unnamed: 0_level_0                                 Unnamed: 1_level_0  \
#               HDI rank                                            Country
#     Unnamed: 0_level_2                                 Unnamed: 1_level_2
# 0                  NaN                        VERY HIGH HUMAN DEVELOPMENT
# 1                  1.0                                        Switzerland
# 2                  2.0                                             Norway
# 3                  3.0                                            Iceland
# 4                  4.0                             Hong Kong, China (SAR)
# ..                 ...                                                ...
# 265                NaN                          Column 2: UNDESA (2022a).
# 266                NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 267                NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 268                NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# ...

# %%
data=data.iloc[:230]

# %%
data_limpio=data.drop(index=[0,1,2,3]).reset_index(drop=True)

# %%
data_limpio.columns=data_limpio.iloc[0]
data_limpio=data_limpio.drop(0).reset_index(drop=True)

# %%
nombres_columnas= ["HDI rank","Country","Human Development Index (HDI)","ND","Life expectancy at birth (years)","ND","Expected years of schooling (years)","ND","Mean years of schooling (years)","ND","Gross national income (GNI) per capita (2017 PPP $)","ND","GNI per capita rank minus HDI rank","ND","HDI rank (2020)"]

# %%
data_limpio.columns=nombres_columnas

# %%
eliminar_col=data_limpio.columns[[3,5,7,9,11,13]]
data_limpio=data_limpio.drop(columns=eliminar_col)

# %%
filas= [8,75,125,170,203]

# %%
for index in filas:
    nombre=data_limpio.loc[index,"Country"]
    data_limpio.loc[index + 1:, "Human_development_groups"] = nombre

# %%
data_limpio=data_limpio.drop(index=filas).reset_index(drop=True)

# %%
data_limpio["Human_development_groups_num"]=data_limpio["Human_development_groups"]
mapper1={"Low human development": 1, "Medium human development": 2, "High human development": 3, "Very high human development": 4}

# %%
data_limpio["Human_development_groups_num"] = data_limpio["Human_development_groups_num"].replace(mapper1)

# %%
convertir=data_limpio.columns.drop(["Country"])

# %%
data_limpio[convertir]=data_limpio[convertir].apply(lambda x: x.astype(str).str.replace(",","."))

# %%
data_limpio[convertir]=data_limpio[convertir].apply(pd.to_numeric, errors="coerce")
data_limpio
# Out:
#      HDI rank                                            Country  \
# 0         5.0                                          Australia
# 1         6.0                                            Denmark
# 2         7.0                                             Sweden
# 3         8.0                                            Ireland
# 4         9.0                                            Germany
# ..        ...                                                ...
# 215       NaN  a. Data refer to 2021 or the most recent year ...
# 216       NaN  b. Based on countries for which a Human Develo...
# 217       NaN  c. In calculating the HDI value, expected year...
# 218       NaN  d. In calculating the HDI value, life expectan...
# 219       NaN  e. Updated by HDRO based on data from UNESCO I...
#
#      Human Development Index (HDI)  Life expectancy at birth (years)  \
# 0                            0.951                              84.5
# ...

# %%
data_limpio1=data_limpio.drop(data_limpio.columns[[7,8]], axis=1)
data_limpio
# Out:
#      HDI rank                                            Country  \
# 0         5.0                                          Australia
# 1         6.0                                            Denmark
# 2         7.0                                             Sweden
# 3         8.0                                            Ireland
# 4         9.0                                            Germany
# ..        ...                                                ...
# 215       NaN  a. Data refer to 2021 or the most recent year ...
# 216       NaN  b. Based on countries for which a Human Develo...
# 217       NaN  c. In calculating the HDI value, expected year...
# 218       NaN  d. In calculating the HDI value, life expectan...
# 219       NaN  e. Updated by HDRO based on data from UNESCO I...
#
#      Human Development Index (HDI)  Life expectancy at birth (years)  \
# 0                            0.951                              84.5
# ...

# %%
data_limpio1=data_limpio.dropna(subset=["HDI rank"])

# %%
data_limpio1
# Out:
#      HDI rank                   Country  Human Development Index (HDI)  \
# 0         5.0                 Australia                          0.951
# 1         6.0                   Denmark                          0.948
# 2         7.0                    Sweden                          0.947
# 3         8.0                   Ireland                          0.945
# 4         9.0                   Germany                          0.942
# ..        ...                       ...                            ...
# 181     187.0                   Burundi                          0.426
# 182     188.0  Central African Republic                          0.404
# 183     189.0                     Niger                          0.400
# 184     190.0                      Chad                          0.394
# 185     191.0               South Sudan                          0.385
#
#      Life expectancy at birth (years)  Expected years of schooling (years)  \
# ...

# %%
data_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 11 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   HDI rank                                             183 non-null    float64
#  1   Country                                              214 non-null    object
#  2   Human Development Index (HDI)                        198 non-null    float64
#  3   Life expectancy at birth (years)                     202 non-null    float64
#  4   Expected years of schooling (years)                  200 non-null    float64
#  5   Mean years of schooling (years)                      198 non-null    float64
#  6   Gross national income (GNI) per capita (2017 PPP $)  200 non-null    float64
#  7   GNI per capita rank minus HDI rank                   183 non-null    float64
# ...
